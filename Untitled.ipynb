# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_axis=[x for x in range(1000,6001,100)]

# %%
with open('/root/docs/HDFS-Sim/statistics/data_0SSD.txt') as file:
    a = file.read()
y = a.split('\n')
y = y[:len(y) - 1:]
y_axis0 = [int(x) for x in y]

# %%
with open('/root/docs/HDFS-Sim/statistics/data_100SSD.txt') as file:
    a = file.read()
y = a.split('\n')
y = y[:len(y) - 1:]
y_axis100 = [int(x) for x in y]

# %%
with open('/root/docs/HDFS-Sim/statistics/data_30SSD.txt') as file:
    a = file.read()
y = a.split('\n')
y = y[:len(y) - 1:]
y_axis30 = [int(x) for x in y]

# %%
plt.plot(x_axis,y_axis0,label="SSD % = 0")
plt.plot(x_axis,y_axis30,label="SSD % = 30")
plt.plot(x_axis,y_axis100,label="SSD % = 100")

plt.xlabel("Number of blocks (128 mb)")
plt.ylabel("Power consumed in Watts")
plt.legend()
plt.title("Power consumed for 100 nodes")
plt.show()
